# %%
import matplotlib.pyplot as plt
import pandas as pd
start_ds = pd.read_csv('kaggle_id.csv', delimiter=";")

start_ds.head(5)
# Out:
# C:\Users\denis\AppData\Local\Temp\ipykernel_26856\2248021781.py:3: DtypeWarning: Columns (225,243,276,278,281,292,293,300) have mixed types. Specify dtype option on import or set low_memory=False.
#   start_ds = pd.read_csv('kaggle_id.csv', delimiter=";")
#    Індекс  Duration (in seconds)     Q2   Q3       Q4   Q5      Q6_1 Q6_2  \
# 0       1                    121  30-34  Man    India   No       NaN  NaN
# 1       2                    462  30-34  Man  Algeria   No       NaN  NaN
# 2       3                    293  18-21  Man    Egypt  Yes  Coursera  edX
# 3       4                    851  55-59  Man   France   No  Coursera  NaN
# 4       5                    232  45-49  Man    India  Yes       NaN  NaN
#
#                    Q6_3      Q6_4  ...                            Q44_4  \
# 0                   NaN       NaN  ...                              NaN
# 1                   NaN       NaN  ...                              NaN
# ...

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q1
Welcome to the 2022 Kaggle Machine Learning and Data Science Survey! It should take roughly 10 to 15
minutes to complete this survey. Anonymized survey results will be released publicly at the end of the
year.

# %%
duration_sum = start_ds['Duration (in seconds)'].sum()
duration_count = start_ds['Duration (in seconds)'].count()
time=duration_sum/duration_count
# Вивести результати
print("Тривалість опитавання в секундах")
print(time)
# Out:
# Тривалість опитавання в секундах
# 10090.095845313997

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q21
What is your age (# years)?

# %%
position_counts = start_ds['Q2'].value_counts()

# Вивести результати
print("Вік респодентів")
print(position_counts)
# Out:
# Кількість посад за категоріями у стовпці Q23:
# Q2
# 18-21    4559
# 25-29    4472
# 22-24    4283
# 30-34    2972
# 35-39    2353
# 40-44    1927
# 45-49    1253
# 50-54     914
# 55-59     611
# 60-69     526
# 70+       127
# Name: count, dtype: int64

# %%
# Create a bar chart
plt.bar(position_counts.index, position_counts.values)
plt.xlabel("ВІК")
plt.ylabel("Кількість респондентів")
plt.title("Розподіл за віком")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the chart
plt.tight_layout()
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q3
What is your gender?
● Man
● Woman
● Nonbinary
● Prefer not to say
● Prefer to self-describe

# %%
position_counts = start_ds['Q3'].value_counts()

# Вивести результати
print("Стать респодентів")
print(position_counts)
# Out:
# Стать респодентів
# Q3
# Man                        18266
# Woman                       5286
# Prefer not to say            334
# Nonbinary                     78
# Prefer to self-describe       33
# Name: count, dtype: int64

# %%
plt.bar(position_counts.index, position_counts.values)
plt.xlabel("Стать")
plt.ylabel("Кількість респондентів")
plt.title("Розподіл за статтю")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Розподіл за статтю")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q4
In which country do you currently reside?

# %%
country_counts = start_ds['Q4'].value_counts()
country_count = len(start_ds['Q4'].unique())
# Вивести результати
print("Країни респодентів")
print(country_counts)
print("\nКількість країн")
print(country_count)
# Out:
# Країни респодентів
# Q4
# India                                                   8792
# United States of America                                2920
# Other                                                   1430
# Brazil                                                   833
# Nigeria                                                  731
# Pakistan                                                 620
# Japan                                                    556
# China                                                    453
# Egypt                                                    383
# Mexico                                                   380
# Indonesia                                                376
# Turkey                                                   345
# Russia                                                   324
# South Korea                                              317
# France                                                   262
# ...

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q5
Are you currently a student? (high school, university, or graduate)
● Yes
● No

# %%
studetnt_counts = start_ds['Q5'].value_counts()
print("Студент чи ні")
print(studetnt_counts)
# Out:
# Студент чи ні
# Q5
# No     12036
# Yes    11961
# Name: count, dtype: int64

# %%
plt.pie(studetnt_counts.values, labels=studetnt_counts.index, autopct="%1.1f%%")
plt.title("Студент чи ні")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 6_1  - 6_12
On which platforms have you begun or completed data science courses? (Select all that apply)
● Coursera
● edX
● Kaggle Learn Courses
● DataCamp
● Fast.ai
● Udacity
● Udemy
● LinkedIn Learning
● Cloud-certification programs (direct from AWS, Azure, GCP, or similar)
● University Courses (resulting in a university degree)
● None
● Other

# %%
# Вибираємо стовпці від Q6_1 до Q6_12
columns_range = [f'Q6_{i}' for i in range(1, 13)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#            Q6_1 Q6_2                  Q6_3      Q6_4 Q6_5     Q6_6   Q6_7  \
# 0           NaN  NaN                   NaN       NaN  NaN      NaN    NaN
# 1           NaN  NaN                   NaN       NaN  NaN      NaN    NaN
# 2      Coursera  edX                   NaN  DataCamp  NaN  Udacity  Udemy
# 3      Coursera  NaN  Kaggle Learn Courses       NaN  NaN      NaN  Udemy
# 4           NaN  NaN                   NaN       NaN  NaN      NaN    NaN
# ...         ...  ...                   ...       ...  ...      ...    ...
# 23992       NaN  NaN                   NaN       NaN  NaN      NaN    NaN
# 23993       NaN  NaN                   NaN       NaN  NaN      NaN    NaN
# 23994       NaN  NaN                   NaN  DataCamp  NaN      NaN  Udemy
# 23995       NaN  NaN  Kaggle Learn Courses       NaN  NaN  Udacity    NaN
# 23996       NaN  NaN                   NaN       NaN  NaN      NaN    NaN
#
#                     Q6_8 Q6_9  \
# 0                    NaN  NaN
# ...

# %%
question_counts = {'Q6_1': 0, 'Q6_2': 0, 'Q6_3': 0, 'Q6_4': 0, 'Q6_5': 0,
                   'Q6_6': 0, 'Q6_7': 0, 'Q6_8': 0, 'Q6_9': 0, 'Q6_10': 0,
                   'Q6_11': 0, 'Q6_12': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 9699
# 2474
# 6628
# 3718
# 944
# 2199
# 6116
# 2766
# 1821
# 6780
# 0
# 5669

# %%
emount_counts = start_ds['Q6_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q6_Emount
# 1     9017
# 2     4946
# 3     3487
# 0     2644
# 4     1986
# 5      942
# 6      506
# 7      231
# 8      110
# 10      66
# 9       43
# 11      19
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 7_1  - 7_7
What products or platforms did you find to be most helpful when you first started studying data
science? (Select all that apply)
● University courses
● Online courses (Coursera, EdX, etc)
● Social media platforms (Reddit, Twitter, etc)
● Video platforms (YouTube, Twitch, etc)
● Kaggle (notebooks, competitions, etc)
● None / I do not study data science
● Other

# %%
columns_range = [f'Q7_{i}' for i in range(1, 8)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                      Q7_1                                 Q7_2  \
# 0                     NaN                                  NaN
# 1      University courses                                  NaN
# 2                     NaN  Online courses (Coursera, EdX, etc)
# 3                     NaN  Online courses (Coursera, EdX, etc)
# 4      University courses                                  NaN
# ...                   ...                                  ...
# 23992  University courses                                  NaN
# 23993  University courses                                  NaN
# 23994                 NaN  Online courses (Coursera, EdX, etc)
# 23995                 NaN                                  NaN
# 23996                 NaN                                  NaN
#
#                                                 Q7_3  \
# 0                                                NaN
# 1                                                NaN
# ...

# %%
question_counts = {'Q7_1': 0, 'Q7_2': 0, 'Q7_3': 0, 'Q7_4': 0, 'Q7_5': 0,
                   'Q7_6': 0, 'Q7_7': 0 }


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 6851
# 13714
# 3310
# 12871
# 12700
# 1022
# 1944

# %%
emount_counts = start_ds['Q7_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)
# Out:
# Кількість вибору
# Q7_Emount
# 1    7867
# 2    6726
# 3    6061
# 4    2348
# 5     646
# 0     301
# 6      48
# Name: count, dtype: int64

# %%
emount_counts = start_ds['Q6_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q6_Emount
# 1     9017
# 2     4946
# 3     3487
# 0     2644
# 4     1986
# 5      942
# 6      506
# 7      231
# 8      110
# 10      66
# 9       43
# 11      19
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q8
What is the highest level of formal education that you have attained or plan to attain within the next 2
years?
● No formal education past high school
● Some college/university study without earning a bachelor’s degree
● Bachelor’s degree
● Master’s degree
● Doctoral degree
● Professional doctorate
● I prefer not to answer

# %%
position_counts = start_ds['Q8'].value_counts()
print("ступінь освіти")
print(position_counts)
# Out:
# ступінь освіти
# Q8
# Master’s degree                                                      9142
# Bachelor’s degree                                                    7625
# Doctoral degree                                                      2657
# Some college/university study without earning a bachelor’s degree    1431
# I prefer not to answer                                               1394
# Professional doctorate                                                585
# No formal education past high school                                  564
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Розподіл за ступенем здобутої освіти")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Have you ever published any academic research (papers, preprints, conference proceedings, etc)?
● Yes
● No

# %%
position_counts = start_ds['Q9'].value_counts()
print("Наявність публікацій")
print(position_counts)
# Out:
# Наявність публікацій
# Q9
# No     7117
# Yes    5244
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Наявність публікацій")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 10_1-10_3
Did your research make use of machine learning? (select multiple)
● Yes, the research made advances related to some novel machine learning method (theoretical
research)
● Yes, the research made use of machine learning as a tool (applied research)
● No

# %%
columns_range = [f'Q10_{i}' for i in range(1, 4)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q10_1                                              Q10_2 Q10_3
# 0       NaN                                                NaN   NaN
# 1       NaN                                                NaN    No
# 2       NaN                                                NaN   NaN
# 3       NaN                                                NaN   NaN
# 4       NaN                                                NaN   NaN
# ...     ...                                                ...   ...
# 23992   NaN                                                NaN   NaN
# 23993   NaN                                                NaN   NaN
# 23994   NaN                                                NaN    No
# 23995   NaN  Yes, the research made use of machine learning...   NaN
# 23996   NaN                                                NaN   NaN
#
# [23997 rows x 3 columns]

# %%
question_counts = {'Q10_1': 0, 'Q10_2': 0, 'Q10_3': 0 }


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 1549
# 2463
# 1913

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q11
For how many years have you been writing code and/or programming?
● I have never written code
● < 1 years
● 1-2 years
● 3-5 years
● 5-10 years
● 10-20 years
● 20+ years

# %%
position_counts = start_ds['Q11'].value_counts()
print("Кількість років програмування")
print(position_counts)
# Out:
# Кількість років програмування
# Q11
# 1-3 years                    6459
# < 1 years                    5454
# 3-5 years                    3399
# 5-10 years                   2556
# I have never written code    2037
# 10-20 years                  1801
# 20+ years                    1537
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Кількість років програмування")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 12_1-12_15
What programming languages do you use on a regular basis? (Select all that apply)
● Python
● R
● SQL
● C
● C++
● Java
● Javascript
● Julia
● Bash
● MATLAB
● None
● Other
● C#
● PHP
● Go

# %%
columns_range = [f'Q12_{i}' for i in range(1, 16)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#         Q12_1 Q12_2 Q12_3 Q12_4 Q12_5 Q12_6 Q12_7       Q12_8 Q12_9 Q12_10  \
# 0         NaN   NaN   NaN   NaN   NaN   NaN   NaN         NaN   NaN    NaN
# 1         NaN   NaN   NaN   NaN   NaN   NaN  Java         NaN   NaN    NaN
# 2      Python   NaN   SQL     C   NaN   NaN   NaN         NaN   NaN    NaN
# 3      Python   NaN   SQL   NaN   NaN   NaN   NaN         NaN  Bash    NaN
# 4      Python   NaN   NaN   NaN   NaN   C++  Java         NaN   NaN    NaN
# ...       ...   ...   ...   ...   ...   ...   ...         ...   ...    ...
# 23992  Python     R   SQL   NaN   NaN   NaN   NaN         NaN   NaN    NaN
# 23993  Python   NaN   SQL   NaN   NaN   NaN   NaN         NaN   NaN    NaN
# 23994  Python   NaN   SQL   NaN   NaN   NaN   NaN         NaN   NaN    NaN
# 23995  Python     R   NaN   NaN   NaN   NaN   NaN         NaN  Bash    NaN
# 23996  Python   NaN   NaN   NaN   NaN   NaN   NaN  Javascript   NaN    NaN
#
#        Q12_11 Q12_12 Q12_13  Q12_14 Q12_15
# ...

# %%
question_counts = {'Q12_1': 0, 'Q12_2': 0, 'Q12_3': 0, 'Q12_4': 0, 'Q12_5': 0,
                   'Q12_6': 0, 'Q12_7': 0, 'Q12_8': 0, 'Q12_9': 0 , 'Q12_10': 0, 'Q12_11': 0, 'Q12_12': 0, 'Q12_13': 0, 'Q12_14': 0, 'Q12_15': 0    }


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 18653
# 4571
# 9620
# 3801
# 1473
# 4549
# 3862
# 3489
# 1674
# 1443
# 2441
# 296
# 322
# 0
# 1342

# %%
emount_counts = start_ds['Q12_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)
# Out:
# Кількість вибору
# Q12_Emount
# 2     6071
# 1     4975
# 3     4568
# 0     3118
# 4     2482
# 5     1369
# 6      679
# 7      358
# 8      193
# 9      101
# 10      44
# 11      20
# 13      11
# 14       5
# 12       3
# Name: count, dtype: int64

# %%
emount_counts = start_ds['Q12_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q12_Emount
# 2     6071
# 1     4975
# 3     4568
# 0     3118
# 4     2482
# 5     1369
# 6      679
# 7      358
# 8      193
# 9      101
# 10      44
# 11      20
# 13      11
# 14       5
# 12       3
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 13_1-13_14
#Which of the following integrated development environments (IDE's) do you use on a regular basis?
(Select all that apply)
● JupyterLab
● RStudio / Posit
● Visual Studio
● Visual Studio Code (VSCode)
● PyCharm
● Spyder
● Notepad++
● Sublime Text
● Vim, Emacs, or similar
● MATLAB
● Jupyter Notebook
● IntelliJ
● None
● Other

# %%
columns_range = [f'Q13_{i}' for i in range(1, 15)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#              Q13_1      Q13_2 Q13_3                          Q13_4      Q13_5  \
# 0              NaN        NaN   NaN                            NaN        NaN
# 1              NaN        NaN   NaN                            NaN        NaN
# 2      JupyterLab         NaN   NaN                            NaN        NaN
# 3              NaN        NaN   NaN   Visual Studio Code (VSCode)         NaN
# 4              NaN        NaN   NaN   Visual Studio Code (VSCode)    PyCharm
# ...            ...        ...   ...                            ...        ...
# 23992          NaN   RStudio    NaN   Visual Studio Code (VSCode)    PyCharm
# 23993          NaN        NaN   NaN                            NaN        NaN
# 23994          NaN        NaN   NaN                            NaN   PyCharm
# 23995          NaN   RStudio    NaN                            NaN   PyCharm
# 23996          NaN        NaN   NaN   Visual Studio Code (VSCode)         NaN
#
# ...

# %%
question_counts = {'Q13_1': 0, 'Q13_2': 0, 'Q13_3': 0, 'Q13_4': 0, 'Q13_5': 0,
                   'Q13_6': 0, 'Q13_7': 0, 'Q13_8': 0, 'Q13_9': 0, 'Q13_10': 0,
                   'Q13_11': 0, 'Q13_12': 0,  'Q13_13': 0, 'Q13_14': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 4887
# 3824
# 4416
# 9976
# 6099
# 2880
# 3891
# 2218
# 1448
# 2302
# 13684
# 1612
# 0
# 1474

# %%
emount_counts = start_ds['Q13_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)
plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q13_Emount
# 2     5365
# 3     4776
# 1     4102
# 0     3814
# 4     2944
# 5     1541
# 6      781
# 7      348
# 8      154
# 9       86
# 10      38
# 12      24
# 11      19
# 13       5
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 14_1-14_16
Do you use any of the following hosted notebook products? (Select all that apply)
● Kaggle Notebooks
● Colab Notebooks
● Azure Notebooks
● Code Ocean
● IBM Watson Studio
● Amazon Sagemaker Studio
● Amazon Sagemaker Studio Lab
● Amazon EMR Notebooks
● Google Cloud Vertex AI Workbench
● Hex Workspaces
● Noteable Notebooks
● Databricks Collaborative Notebooks
● Deepnote Notebooks
● Gradient Notebooks
● None
● Other

# %%
columns_range = [f'Q14_{i}' for i in range(1, 17)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                    Q14_1            Q14_2 Q14_3 Q14_4                Q14_5  \
# 0                    NaN              NaN   NaN   NaN                  NaN
# 1                    NaN              NaN   NaN   NaN                  NaN
# 2       Kaggle Notebooks              NaN   NaN   NaN   IBM Watson Studio
# 3       Kaggle Notebooks  Colab Notebooks   NaN   NaN                  NaN
# 4                    NaN              NaN   NaN   NaN                  NaN
# ...                  ...              ...   ...   ...                  ...
# 23992   Kaggle Notebooks  Colab Notebooks   NaN   NaN                  NaN
# 23993                NaN              NaN   NaN   NaN                  NaN
# 23994                NaN              NaN   NaN   NaN                  NaN
# 23995                NaN  Colab Notebooks   NaN   NaN                  NaN
# 23996   Kaggle Notebooks  Colab Notebooks   NaN   NaN                  NaN
#
# ...

# %%
question_counts = {'Q14_1': 0, 'Q14_2': 0, 'Q14_3': 0, 'Q14_4': 0, 'Q14_5': 0,
                   'Q14_6': 0, 'Q14_7': 0, 'Q14_8': 0, 'Q14_9': 0, 'Q14_10': 0,
                   'Q14_11': 0, 'Q14_12': 0,  'Q14_13': 0, 'Q14_14': 0, 'Q14_15': 0, 'Q14_16': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 7478
# 8929
# 885
# 158
# 964
# 735
# 545
# 260
# 870
# 77
# 299
# 610
# 294
# 244
# 0
# 582

# %%
emount_counts = start_ds['Q14_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)
plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q14_Emount
# 0     10590
# 1      7011
# 2      4594
# 3      1172
# 4       366
# 5       131
# 6        51
# 7        30
# 8        14
# 14       13
# 10        6
# 12        5
# 9         4
# 15        4
# 11        4
# 13        2
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 15_1-15_15
Do you use any of the following data visualization libraries on a regular basis? (Select all that apply)
● Matplotlib
● Seaborn
● Plotly / Plotly Express
● Ggplot / ggplot2
● Shiny
● D3 js
● Altair
● Bokeh
● Geoplotlib
● Leaflet / Folium
● Pygal
● Dygraphs
● Highcharter
● None
● Other

# %%
columns_range = [f'Q15_{i}' for i in range(1, 16)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#               Q15_1      Q15_2                      Q15_3               Q15_4  \
# 0               NaN        NaN                        NaN                 NaN
# 1       Matplotlib         NaN                        NaN                 NaN
# 2       Matplotlib    Seaborn    Plotly / Plotly Express                  NaN
# 3       Matplotlib    Seaborn                         NaN                 NaN
# 4               NaN        NaN                        NaN                 NaN
# ...             ...        ...                        ...                 ...
# 23992   Matplotlib    Seaborn                         NaN   Ggplot / ggplot2
# 23993           NaN        NaN                        NaN                 NaN
# 23994           NaN   Seaborn                         NaN                 NaN
# 23995   Matplotlib         NaN                        NaN   Ggplot / ggplot2
# 23996   Matplotlib    Seaborn    Plotly / Plotly Express                  NaN
#
# ...

# %%
question_counts = {'Q15_1': 0, 'Q15_2': 0, 'Q15_3': 0, 'Q15_4': 0, 'Q15_5': 0,
                   'Q15_6': 0, 'Q15_7': 0, 'Q15_8': 0, 'Q15_9': 0, 'Q15_10': 0,
                   'Q15_11': 0, 'Q15_12': 0,  'Q15_13': 0, 'Q15_14': 0, 'Q15_15': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 14010
# 10512
# 5078
# 4145
# 1043
# 734
# 300
# 771
# 1167
# 554
# 318
# 225
# 198
# 0
# 691

# %%
emount_counts = start_ds['Q15_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q15_Emount
# 0     7671
# 2     5923
# 1     4007
# 3     3662
# 4     1654
# 5      660
# 6      225
# 7       99
# 8       44
# 13      19
# 9       11
# 10      10
# 14       5
# 11       4
# 12       3
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q16
For how many years have you used machine learning methods?
● I do not use machine learning methods
● Under 1 year
● 1-2 years
● 2-3 years
● 3-4 years
● 4-5 years
● 5-10 years
● 10-20 years
● 20 or more years

# %%
position_counts = start_ds['Q16'].value_counts()
print("Машинне навчання - кількість років застосування")
print(position_counts)
# Out:
# Машинне навчання - кількість років застосування
# Q16
# Under 1 year                             7221
# 1-2 years                                3720
# I do not use machine learning methods    3419
# 2-3 years                                1947
# 5-10 years                               1090
# 3-4 years                                1053
# 4-5 years                                 950
# 10-20 years                               483
# 20 or more years                            3
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Машинне навчання - кількість років застосування")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 17_1  - 17_15
Which of the following machine learning frameworks do you use on a regular basis? (Select all that
apply)
● Scikit-learn
● TensorFlow
● Keras
● PyTorch
● Fast.ai
● Xgboost
● LightGBM
● CatBoost
● Caret
● Tidymodels
● JAX
● PyTorch Lightning
● Huggingface
● None
● Other

# %%
columns_range = [f'Q17_{i}' for i in range(1, 16)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                  Q17_1          Q17_2    Q17_3      Q17_4 Q17_5      Q17_6  \
# 0                  NaN            NaN      NaN        NaN   NaN        NaN
# 1        Scikit-learn     TensorFlow       NaN   PyTorch    NaN        NaN
# 2        Scikit-learn             NaN      NaN   PyTorch    NaN   Xgboost
# 3        Scikit-learn             NaN      NaN   PyTorch    NaN        NaN
# 4                  NaN            NaN      NaN        NaN   NaN        NaN
# ...                ...            ...      ...        ...   ...        ...
# 23992    Scikit-learn     TensorFlow    Keras    PyTorch    NaN   Xgboost
# 23993              NaN            NaN      NaN        NaN   NaN        NaN
# 23994              NaN            NaN      NaN        NaN   NaN   Xgboost
# 23995    Scikit-learn             NaN      NaN        NaN   NaN        NaN
# 23996    Scikit-learn     TensorFlow       NaN        NaN   NaN        NaN
#
# ...

# %%
question_counts = {'Q17_1': 0, 'Q17_2': 0, 'Q17_3': 0, 'Q17_4': 0, 'Q17_5': 0,
                   'Q17_6': 0, 'Q17_7': 0, 'Q17_8': 0, 'Q17_9': 0, 'Q17_10': 0,
                   'Q17_11': 0, 'Q17_12': 0, 'Q17_13': 0, 'Q17_14': 0, 'Q17_15': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 11403
# 7953
# 6575
# 5191
# 648
# 4477
# 1940
# 1165
# 821
# 547
# 252
# 1013
# 1332
# 0
# 620

# %%
emount_counts = start_ds['Q17_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q17_Emount
# 0     9466
# 1     3727
# 3     2981
# 2     2786
# 4     2330
# 5     1276
# 6      709
# 7      368
# 8      195
# 9       80
# 10      37
# 13      19
# 11      14
# 12       6
# 14       3
# Name: count, dtype: int64

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q 18_1  - 18_14
Which of the following ML algorithms do you use on a regular basis? (Select all that apply):
● Linear or Logistic Regression
● Decision Trees or Random Forests
● Gradient Boosting Machines (xgboost, lightgbm, etc)
● Bayesian Approaches
● Evolutionary Approaches
● Dense Neural Networks (MLPs, etc)
● Convolutional Neural Networks
● Generative Adversarial Networks
● Recurrent Neural Networks
● Transformer Networks (BERT, gpt-3, etc)
● Autoencoder Networks (DAE, VAE, etc)
● Graph Neural Networks
● None
● Other

# %%
columns_range = [f'Q18_{i}' for i in range(1, 15)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                                Q18_1                             Q18_2  \
# 0                                NaN                               NaN
# 1                                NaN                               NaN
# 2      Linear or Logistic Regression  Decision Trees or Random Forests
# 3                                NaN                               NaN
# 4                                NaN                               NaN
# ...                              ...                               ...
# 23992  Linear or Logistic Regression  Decision Trees or Random Forests
# 23993  Linear or Logistic Regression  Decision Trees or Random Forests
# 23994  Linear or Logistic Regression  Decision Trees or Random Forests
# 23995                            NaN  Decision Trees or Random Forests
# 23996  Linear or Logistic Regression  Decision Trees or Random Forests
#
#                                                    Q18_3                Q18_4  \
# ...

# %%
question_counts = {'Q18_1': 0, 'Q18_2': 0, 'Q18_3': 0, 'Q18_4': 0, 'Q18_5': 0,
                   'Q18_6': 0, 'Q18_7': 0, 'Q18_8': 0, 'Q18_9': 0, 'Q18_10': 0,
                   'Q18_11': 0, 'Q18_12': 0, 'Q18_13': 0, 'Q18_14': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 11338
# 9373
# 5506
# 3661
# 823
# 3476
# 6006
# 1166
# 3451
# 2196
# 1234
# 1422
# 0
# 538

# %%
emount_counts = start_ds['Q18_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q18_Emount
# 0     9459
# 3     3099
# 2     3084
# 1     2444
# 4     2314
# 5     1456
# 6      863
# 7      564
# 8      311
# 9      145
# 10     117
# 12      89
# 11      44
# 13       8
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q19
Which categories of computer vision methods do you use on a regular basis? (Select all that apply)
● General purpose image/video tools (PIL, cv2, skimage, etc)
● Image segmentation methods (U-Net, Mask R-CNN, etc)
● Object detection methods (YOLOv6, RetinaNet, etc)
● Image classification and other general purpose networks (VGG, Inception, ResNet,
ResNeXt, NASNet, EfficientNet, etc)
● Vision transformer networks (ViT, DeiT, BiT, BEiT, Swin, etc)
● Generative Networks (GAN, VAE, etc)
● None
● Other

# %%
# Вибираємо стовпці від Q19_1 до Q19_8
columns_range = [f'Q19_{i}' for i in range(1, 9)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q19_1                                              Q19_2  \
# 0       NaN                                                NaN
# 1       NaN                                                NaN
# 2       NaN                                                NaN
# 3       NaN                                                NaN
# 4       NaN                                                NaN
# ...     ...                                                ...
# 23992   NaN  Image segmentation methods (U-Net, Mask R-CNN,...
# 23993   NaN                                                NaN
# 23994   NaN                                                NaN
# 23995   NaN                                                NaN
# 23996   NaN                                                NaN
#
#                                                 Q19_3  \
# 0                                                 NaN
# 1                                                 NaN
# ...

# %%
question_counts = {'Q19_1': 0, 'Q19_2': 0, 'Q19_3': 0, 'Q19_4': 0, 'Q19_5': 0,
                   'Q19_6': 0, 'Q19_7': 0, 'Q19_8': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 2293
# 2495
# 2525
# 3664
# 1343
# 782
# 0
# 146

# %%
emount_counts = start_ds['Q19_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q19_Emount
# 0    18734
# 1     1499
# 2     1484
# 3     1094
# 4      684
# 5      265
# 6      221
# 7       16
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q20
Which of the following natural language processing (NLP) methods do you use on a regular basis?
(Select all that apply)
● Word embeddings/vectors (GLoVe, fastText, word2vec)
● Encoder-decoder models (seq2seq, vanilla transformers)
● Contextualized embeddings (ELMo, CoVe)
● Transformer language models (GPT-3, BERT, XLnet, etc)
● None
● Other

# %%
# Вибираємо стовпці від Q20_1 до Q20_6
columns_range = [f'Q20_{i}' for i in range(1, 7)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                                                    Q20_1  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3      Word embeddings/vectors (GLoVe, fastText, word...
# 4                                                    NaN
# ...                                                  ...
# 23992                                                NaN
# 23993                                                NaN
# 23994                                                NaN
# 23995                                                NaN
# 23996                                                NaN
#
#                                                    Q20_2 Q20_3  \
# 0                                                    NaN   NaN
# 1                                                    NaN   NaN
# 2                                                    NaN   NaN
# ...

# %%
question_counts = {'Q20_1': 0, 'Q20_2': 0, 'Q20_3': 0, 'Q20_4': 0, 'Q20_5': 0,
                   'Q20_6': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 2241
# 1701
# 685
# 2219
# 0
# 126

# %%
emount_counts = start_ds['Q20_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q20_Emount
# 0    20678
# 1     1152
# 2     1100
# 3      660
# 4      395
# 5       12
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 21_1-21_10
Do you download pre-trained model weights from any of the following services? (Select all that apply)
● Tfhub.dev
● Pytorch hub
● Huggingface models
● Timm
● Jumpstart
● ONNX models
● NVIDIA NGC models
● Kaggle datasets
● Other storage services (i.e. google drive)
● I do not download pre-trained model weights on a regular basis

# %%
columns_range = [f'Q21_{i}' for i in range(1, 11)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                    Q21_1 Q21_2                 Q21_3 Q21_4 Q21_5  \
# 0                    NaN   NaN                   NaN   NaN   NaN
# 1                    NaN   NaN                   NaN   NaN   NaN
# 2                    NaN   NaN                   NaN   NaN   NaN
# 3                    NaN   NaN   Huggingface Models    NaN   NaN
# 4                    NaN   NaN                   NaN   NaN   NaN
# ...                  ...   ...                   ...   ...   ...
# 23992    TensorFlow Hub    NaN                   NaN   NaN   NaN
# 23993                NaN   NaN                   NaN   NaN   NaN
# 23994                NaN   NaN                   NaN   NaN   NaN
# 23995                NaN   NaN                   NaN   NaN   NaN
# 23996                NaN   NaN                   NaN   NaN   NaN
#
#                Q21_6 Q21_7              Q21_8  \
# 0                NaN   NaN                NaN
# 1                NaN   NaN                NaN
# ...

# %%
question_counts = {'Q21_1': 0, 'Q21_2': 0, 'Q21_3': 0, 'Q21_4': 0, 'Q21_5': 0,
                   'Q21_6': 0, 'Q21_7': 0, 'Q21_8': 0,
                   'Q21_9': 0, 'Q21_10': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 3087
# 2012
# 1793
# 434
# 237
# 418
# 630
# 5422
# 7122
# 703

# %%
emount_counts = start_ds['Q21_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q21_Emount
# 0    15699
# 1     4561
# 2     2052
# 3     1094
# 4      361
# 5      139
# 8       41
# 6       36
# 7       10
# 9        4
# Name: count, dtype: int64

# %%
Q22
Which of the following ML model hubs/repositories do you use most often? (Select all that apply)
● » Tfhub.dev
● » Pytorch hub
● » Huggingface models
● » Timm
● » Jumpstart
● » ONNX models
● » NVIDIA NGC models
● » Kaggle datasets
● » Other storage services (i.e. google drive)

# %%
position_counts = start_ds['Q22'].value_counts()
print("Хаби/репозиторії машинного навчання ")
print(position_counts)
# Out:
# Хаби/репозиторії машинного навчання
# Q22
#  Kaggle datasets                              1618
#   TensorFlow Hub                               799
#  Huggingface Models                            502
#  PyTorch Hub                                   412
#  Timm                                          127
# Other storage services (i.e. google drive)      96
#  NVIDIA NGC models                              69
#  ONNX models                                    46
#  Jumpstart                                      24
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Хаби/репозиторії машинного навчання ")
plt.show()

# %%
#***********************************************************************************
#********************************************************************************

# %%
Q23
Select the title most similar to your current role (or most recent title if retired):
● Data Analyst (Business, Marketing, Financial, Quantitative, etc)
● Data Architect
● Data Engineer
● Data Scientist
● Data Administrator
● Developer Advocate
● Machine Learning/ MLops Engineer
● Manager (Program, Project, Operations, Executive-level, etc)
● Research Scientist
● Software Engineer
● Engineer (non-software)
● Statistician
● Teacher / professor
● Currently not employed
● Other

# %%
position_counts = start_ds['Q23'].value_counts()

# Вивести результати
print("Кількість посад за категоріями у стовпці Q23:")
print(position_counts)
# Out:
# Кількість посад за категоріями у стовпці Q23:
# Q23
# Data Scientist                                                   1929
# Data Analyst (Business, Marketing, Ficial, Quantitative, etc)    1538
# Currently not employed                                           1432
# Software Engineer                                                 980
# Teacher / professor                                               833
# Manager (Program, Project, Operations, Executive-level, etc)      832
# Other                                                             754
# Research Scientist                                                593
# Machine Learning/ MLops Engineer                                  571
# Engineer (non-software)                                           465
# Data Engineer                                                     352
# Statistician                                                      125
# Data Architect                                                     95
# ...

# %%
plt.bar(position_counts.index, position_counts.values)
plt.xlabel("Посада")
plt.ylabel("Кількість респондентів")
plt.title("Розподіл за посадою")

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Show the chart
plt.tight_layout()
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q24
In what industry is your current employer/contract (or your most recent employer if retired)?
● Academics/Education
● Accounting/Finance
● Broadcasting/Communications
● Computers/Technology
● Energy/Mining
● Government/Public Service
● Insurance/Risk Assessment
● Online Service/Internet-based Services
● Marketing/CRM
● Manufacturing/Fabrication
● Medical/Pharmaceutical
● Non-profit/Service
● Retail/Sales
● Shipping/Transportation
● Other

# %%
industry_counts = start_ds['Q24'].value_counts()

# Вивести результати
print("Кількість компаній в галузі за категоріями у стовпці Q24:")
print(position_counts)
# Out:
# Кількість компаній в галузі за категоріями у стовпці Q24:
# Q23
# Data Scientist                                                   1929
# Data Analyst (Business, Marketing, Ficial, Quantitative, etc)    1538
# Currently not employed                                           1432
# Software Engineer                                                 980
# Teacher / professor                                               833
# Manager (Program, Project, Operations, Executive-level, etc)      832
# Other                                                             754
# Research Scientist                                                593
# Machine Learning/ MLops Engineer                                  571
# Engineer (non-software)                                           465
# Data Engineer                                                     352
# Statistician                                                      125
# ...

# %%
plt.bar(industry_counts.index, industry_counts.values)
plt.xlabel("Галузь")
plt.ylabel("Кількість респондентів")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q25
What is the size of the company where you are employed?
● 0-49 employees
● 50-249 employees
● 250-999 employees
● 1000-9,999 employees
● 10,000 or more employees

# %%
size_company = start_ds['Q25'].value_counts()

# Вивести результати
print("Кількість співробітників у компанії за категоріями у стовпці Q25:")
print(size_company)
# Out:
# Кількість співробітників у компанії за категоріями у стовпці Q25:
# Q25
# 0-49 employees              2130
# 10,000 or more employees    2122
# 1000-9,999 employees        1888
# 50-249 employees            1564
# 250-999 employees           1362
# Name: count, dtype: int64

# %%
plt.pie(size_company.values, labels=size_company.index, autopct="%1.1f%%")
plt.title("Кількість співробітників у компагії")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q26
Approximately how many individuals are responsible for data science workloads at your place of
business?
● 0
● 1-2
● 3-4
● 5-9
● 10-14
● 15-19
● 20+

# %%
responsible_ds = start_ds['Q26'].value_counts()

# Вивести результати
print("Кількість співробітників відповідальних за використання машинного навчання у компанії за категоріями у стовпці Q26:\n")
print(responsible_ds)
# Out:
# Кількість співробітників відповідальних за використання машинного навчання у компанії за категоріями у стовпці Q26:
#
# Q26
# 20+      2270
# 1-2      1815
# 0        1457
# 3-4      1392
# 5-9      1141
# 10-14     653
# 15-19     262
# Name: count, dtype: int64

# %%
plt.pie(responsible_ds.values, labels=responsible_ds.index, autopct="%1.1f%%")
plt.title("Кількість співробітників відповідальних за використання машинного навчання у компанії")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q27
Does your current employer incorporate machine learning methods into their business?
● We are exploring ML methods (and may one day put a model into production)
● We use ML methods for generating insights (but do not put working models into production)
● We recently started using ML methods (i.e., models in production for less than 2 years)
● We have well established ML methods (i.e., models in production for more than 2 years)
● No (we do not use ML methods)
● I do not know

# %%
responsible_ds = start_ds['Q27'].value_counts()

# Вивести результати
print("Чи використовує ваш роботодавець методи машинного навчання у своєму бізнесі Q27:\n")
print(responsible_ds)
# Out:
# Чи використовує ваш роботодавець методи машинного навчання у своєму бізнесі Q27:
#
# Q27
# No (we do not use ML methods)                                                                1970
# We have well established ML methods (i.e., models in production for more than 2 years)       1778
# We are exploring ML methods (and may one day put a model into production)                    1552
# I do not know                                                                                1438
# We recently started using ML methods (i.e., models in production for less than 2 years)      1209
# We use ML methods for generating insights (but do not put working models into production)     925
# Name: count, dtype: int64

# %%
plt.pie(responsible_ds.values, labels=responsible_ds.index, autopct="%1.1f%%")
plt.title("Чи використовує ваш роботодавець методи машинного навчання у своєму бізнесі")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 28_1-28_7
Select any activities that make up an important part of your role at work: (Select all that apply)
● Analyze and understand data to influence product or business decisions
● Build and/or run the data infrastructure that my business uses for storing, analyzing, and
operationalizing data
● Build prototypes to explore applying machine learning to new areas
● Build and/or run a machine learning service that operationally improves my product or
workflows
● Experimentation and iteration to improve existing ML models
● Do research that advances the state of the art of machine learning
● None of these activities are an important part of my role at work
● Other

# %%
columns_range = [f'Q28_{i}' for i in range(1, 8)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q28_1 Q28_2                                              Q28_3  \
# 0       NaN   NaN                                                NaN
# 1       NaN   NaN                                                NaN
# 2       NaN   NaN                                                NaN
# 3       NaN   NaN  Build prototypes to explore applying machine l...
# 4       NaN   NaN                                                NaN
# ...     ...   ...                                                ...
# 23992   NaN   NaN                                                NaN
# 23993   NaN   NaN                                                NaN
# 23994   NaN   NaN                                                NaN
# 23995   NaN   NaN                                                NaN
# 23996   NaN   NaN                                                NaN
#
#                                                    Q28_4  \
# 0                                                    NaN
# ...

# %%
question_counts = {'Q28_1': 0, 'Q28_2': 0, 'Q28_3': 0, 'Q28_4': 0, 'Q28_5': 0,
                   'Q28_6': 0, 'Q28_7': 0, 'Q28_8': 0}


for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
print(f"відповідей")
for question, count in question_counts.items():
    print(count)
plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# відповідей
# 4999
# 2622
# 3034
# 2171
# 2352
# 1663
# 1444
# 486

# %%
emount_counts = start_ds['Q28_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q28_Emount
# 0    16789
# 1     2797
# 2     1599
# 3     1190
# 4      748
# 5      487
# 6      374
# 7       13
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q29
What is your current yearly compensation (approximate $USD)?

# %%
size_company = start_ds['Q29'].value_counts()

# Вивести результати
print("Ваша поточна річна винагорода (приблизно дол. США)")
print(size_company)
# Out:
# Ваша поточна річна винагорода (приблизно дол. США)
# Q29
# $0-999              1112
# 10,000-14,999        493
# 30,000-39,999        464
# 1,000-1,999          444
# 40,000-49,999        421
# 100,000-124,999      404
# 5,000-7,499          391
# 50,000-59,999        366
# 7,500-9,999          362
# 150,000-199,999      342
# 20,000-24,999        337
# 60,000-69,999        318
# 15,000-19,999        299
# 70,000-79,999        289
# 25,000-29,999        277
# 2,000-2,999          271
# 125,000-149,999      269
# 3,000-3,999          244
# 4,000-4,999          234
# 80,000-89,999        222
# 90,000-99,999        197
# 200,000-249,999      155
# 250,000-299,999       78
# 300,000-499,999       76
# $500,000-999,999      48
# >$1,000,000           23
# Name: count, dtype: int64

# %%
plt.pie(size_company.values, labels=size_company.index, autopct="%1.1f%%")
plt.title("Ваша поточна річна винагорода ")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q30
Approximately how much money have you spent on machine learning and/or cloud computing
services at home or at work in the past 5 years (approximate $USD)?
● $0 ($USD)
● $1-$99
● $100-$999
● $1000-$9,999
● $10,000-$99,999
● $100,000 or more ($USD)

# %%
responsible_ds = start_ds['Q30'].value_counts()

# Вивести результати
print("Кількість грошей яку ви витратили на послуги машинного навчання та/або хмарних обчислень вдома чи на роботі за останні 5 років  Q30: \n")
print(responsible_ds)
# Out:
# Кількість грошей яку ви витратили на послуги машинного навчання та/або хмарних обчислень вдома чи на роботі за останні 5 років  Q30:
#
# Q30
# $0 ($USD)                  2822
# $100-$999                  2078
# $1000-$9,999               1469
# $1-$99                     1449
# $10,000-$99,999             480
# $100,000 or more ($USD)     186
# Name: count, dtype: int64

# %%
plt.pie(responsible_ds.values, labels=responsible_ds.index, autopct="%1.1f%%")
plt.title("Кількість грошей яку ви витратили на послуги машинного навчання та/або хмарних обчислень")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 31_1-31_12
Which of the following cloud computing platforms do you use? (Select all that apply)
● Amazon Web Services (AWS)
● Microsoft Azure
● Google Cloud Platform (GCP)
● IBM Cloud / Red Hat
● Oracle Cloud
● SAP Cloud
● VMware Cloud
● Alibaba Cloud
● Tencent Cloud
● Huawei Cloud
● None
● Other

# %%
columns_range = [f'Q31_{i}' for i in range(1, 13)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q31_1              Q31_2 Q31_3 Q31_4 Q31_5 Q31_6 Q31_7 Q31_8 Q31_9  \
# 0       NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1       NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2       NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4       NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...     ...                ...   ...   ...   ...   ...   ...   ...   ...
# 23992   NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23993   NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23994   NaN   Microsoft Azure    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23995   NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 23996   NaN                NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#       Q31_10  Q31_11 Q31_12
# 0        NaN     NaN    NaN
# 1        NaN     NaN    NaN
# ...

# %%
question_counts = {'Q31_1': 0, 'Q31_2': 0, 'Q31_3': 0, 'Q31_4': 0, 'Q31_5': 0,
                   'Q31_6': 0, 'Q31_7': 0, 'Q31_8': 0, 'Q31_9': 0, 'Q31_10': 0, 'Q31_11': 0, 'Q31_12': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 2346
# 1416
# 2056
# 287
# 230
# 107
# 155
# 76
# 56
# 47
# 0
# 217

# %%
emount_counts = start_ds['Q31_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q31_Emount
# 0     19897
# 1      2164
# 2      1270
# 3       499
# 4       106
# 5        36
# 6        11
# 10        5
# 8         5
# 7         3
# 11        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 32
Of the cloud platforms that you are familiar with, which has the best developer experience (most
enjoyable to use)?
● » Amazon Web Services (AWS)
● » Microsoft Azure
● » Google Cloud Platform (GCP)
● » IBM Cloud / Red Hat
● » Oracle Cloud
● » SAP Cloud
● » Salesforce Cloud
● » VMware Cloud
● » Alibaba Cloud
● » Tencent Cloud
● » Huawei Cloud
● None were satisfactory
● They all had a similarly enjoyable developer experience
● Other

# %%
responsible_ds = start_ds['Q32'].value_counts()

# Вивести результати
print("Яка хмарна технологія має найкращий досвід розробок \n")
print(responsible_ds)
# Out:
# Яка хмарна технологія має найкращий досвід розробок
#
# Q32
#  Amazon Web Services (AWS)                                 555
#  Google Cloud Platform (GCP)                               501
# They all had a similarly enjoyable developer experience    443
#  Microsoft Azure                                           256
# None were satisfactory                                      72
#  IBM Cloud / Red Hat                                        34
#  Oracle Cloud                                               20
# Other                                                       20
#  VMware Cloud                                               12
#  SAP Cloud                                                   7
#  Alibaba Cloud                                               5
#  Tencent Cloud                                               3
#  Huawei Cloud                                                1
# Name: count, dtype: int64

# %%
plt.pie(responsible_ds.values, labels=responsible_ds.index, autopct="%1.1f%%")
plt.title("Яка хмарна технологія має найкращий досвід розробок ")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q33
Do you use any of the following cloud computing products? (Select all that apply)
● Amazon Elastic Compute Cloud (EC2)
● Microsoft Azure Virtual Machines
● Google Cloud Compute Engine
● No / None

# %%
# Вибираємо стовпці від Q33_1 до Q33_5
columns_range = [f'Q33_{i}' for i in range(1, 6)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q33_1 Q33_2 Q33_3      Q33_4 Q33_5
# 0       NaN   NaN   NaN        NaN   NaN
# 1       NaN   NaN   NaN        NaN   NaN
# 2       NaN   NaN   NaN        NaN   NaN
# 3       NaN   NaN   NaN        NaN   NaN
# 4       NaN   NaN   NaN        NaN   NaN
# ...     ...   ...   ...        ...   ...
# 23992   NaN   NaN   NaN        NaN   NaN
# 23993   NaN   NaN   NaN        NaN   NaN
# 23994   NaN   NaN   NaN  No / None   NaN
# 23995   NaN   NaN   NaN        NaN   NaN
# 23996   NaN   NaN   NaN        NaN   NaN
#
# [23997 rows x 5 columns]

# %%
question_counts = {'Q33_1': 0, 'Q33_2': 0, 'Q33_3': 0, 'Q33_4': 0, 'Q33_5': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 1609
# 887
# 1321
# 930
# 68

# %%
emount_counts = start_ds['Q33_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q33_Emount
# 0    21178
# 1     1978
# 2      620
# 3      217
# 4        4
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 34_1-34_8
Do you use any of the following data storage products? (Select all that apply)
● Amazon Simple Storage Service (S3)
● Amazon Elastic File System (EFS)
● Google Cloud Storage (GCS)
● Google Cloud Filestore
● Microsoft Azure Blob Storage
● Microsoft Azure Files
● No / None
● Other

# %%
columns_range = [f'Q34_{i}' for i in range(1, 9)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q34_1 Q34_2 Q34_3 Q34_4 Q34_5 Q34_6      Q34_7 Q34_8
# 0       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# ...     ...   ...   ...   ...   ...   ...        ...   ...
# 23992   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23993   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23994   NaN   NaN   NaN   NaN   NaN   NaN  No / None   NaN
# 23995   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23996   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
#
# [23997 rows x 8 columns]

# %%
question_counts = {'Q34_1': 0, 'Q34_2': 0, 'Q34_3': 0, 'Q34_4': 0, 'Q34_5': 0, 'Q34_6': 0, 'Q34_7': 0, 'Q34_8': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 615
# 511
# 1624
# 447
# 1288
# 481
# 771
# 74

# %%
emount_counts = start_ds['Q34_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q34_Emount
# 0    20262
# 1     2374
# 2      931
# 3      259
# 4      107
# 6       48
# 5       15
# 7        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 35_1-35_16
Do you use any of the following data products (relational databases, data warehouses, data lakes,
or similar)? (Select all that apply)
● MySQL
● PostgreSQL
● SQLite
● Oracle Database
● MongoDB
● Snowflake
● IBM Db2
● Microsoft SQL Server
● Microsoft Azure SQL Database
● Amazon Redshift
● Amazon RDS
● Amazon DynamoDB
● Google Cloud BigQuery
● Google Cloud SQL
● None
● Other

# %%
columns_range = [f'Q35_{i}' for i in range(1, 17)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q35_1 Q35_2 Q35_3 Q35_4     Q35_5 Q35_6 Q35_7 Q35_8  \
# 0       NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 1       NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 2       NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 3       NaN   NaN   NaN   NaN  MongoDB    NaN   NaN   NaN
# 4       NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# ...     ...   ...   ...   ...       ...   ...   ...   ...
# 23992   NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 23993   NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 23994   NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 23995   NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
# 23996   NaN   NaN   NaN   NaN       NaN   NaN   NaN   NaN
#
#                                Q35_9 Q35_10 Q35_11 Q35_12 Q35_13 Q35_14  \
# 0                                NaN    NaN    NaN    NaN    NaN    NaN
# 1                                NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
question_counts = {'Q35_1': 0, 'Q35_2': 0, 'Q35_3': 0, 'Q35_4': 0, 'Q35_5': 0, 'Q35_6': 0, 'Q35_7': 0, 'Q35_8': 0, 
                   'Q35_9': 0, 'Q35_10': 0,'Q35_11': 0, 'Q35_12': 0, 'Q35_13': 0, 'Q35_14': 0, 'Q35_15': 0, 'Q35_16': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 2233
# 1516
# 1159
# 688
# 1031
# 399
# 192
# 1203
# 520
# 380
# 505
# 356
# 690
# 439
# 0
# 217

# %%
emount_counts = start_ds['Q35_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q35_Emount
# 0     19755
# 1      1243
# 2      1115
# 3       842
# 4       446
# 5       276
# 6       128
# 7        94
# 8        38
# 9        27
# 10       10
# 14        9
# 12        8
# 11        5
# 15        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 36_1-36_15
Do you use any of the following business intelligence tools? (Select all that apply)
● Amazon QuickSight
● Microsoft Power BI
● Google Data Studio
● Looker
● Tableau
● Qlik Sense
● Domo
● TIBCO Spotfire
● Alteryx
● Sisense
● SAP Analytics Cloud
● Microsoft Azure Synapse
● Microstrategy
● None
● Other

# %%
columns_range = [f'Q36_{i}' for i in range(1, 16)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q36_1 Q36_2 Q36_3 Q36_4    Q36_5 Q36_6 Q36_7 Q36_8 Q36_9 Q36_10 Q36_11  \
# 0       NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1       NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2       NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3       NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4       NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# ...     ...   ...   ...   ...      ...   ...   ...   ...   ...    ...    ...
# 23992   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23993   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23994   NaN   NaN   NaN   NaN  Tableau   NaN   NaN   NaN   NaN    NaN    NaN
# 23995   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23996   NaN   NaN   NaN   NaN      NaN   NaN   NaN   NaN   NaN    NaN    NaN
#
#       Q36_12 Q36_13  Q36_14 Q36_15
# ...

# %%
question_counts = {'Q36_1': 0, 'Q36_2': 0, 'Q36_3': 0, 'Q36_4': 0, 'Q36_5': 0, 'Q36_6': 0, 'Q36_7': 0, 'Q36_8': 0, 
                   'Q36_9': 0, 'Q36_10': 0,'Q36_11': 0, 'Q36_12': 0, 'Q36_13': 0, 'Q36_14': 0, 'Q36_15': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 224
# 1658
# 643
# 166
# 1732
# 207
# 44
# 86
# 132
# 38
# 106
# 167
# 22
# 0
# 191

# %%
emount_counts = start_ds['Q36_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q36_Emount
# 0     20870
# 1      1632
# 2       987
# 3       345
# 4       105
# 5        31
# 6        16
# 7         5
# 13        2
# 10        2
# 9         1
# 14        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 37_1-37_13
Do you use any of the following managed machine learning products? (Select all that apply)
● Amazon SageMaker
● Azure Machine Learning Studio
● Google Cloud Vertex AI
● DataRobot
● Databricks
● Dataiku
● Alteryx
● Rapidminer
● C3.ai
● Domino Data Lab
● H2O AI Cloud
● No / None
● Other

# %%
columns_range = [f'Q37_{i}' for i in range(1, 14)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q37_1 Q37_2 Q37_3 Q37_4 Q37_5 Q37_6 Q37_7 Q37_8 Q37_9 Q37_10 Q37_11  \
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...    ...    ...
# 23992   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23993   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23994   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23995   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
# 23996   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN    NaN
#
#           Q37_12 Q37_13
# 0            NaN    NaN
# 1            NaN    NaN
# ...

# %%
question_counts = {'Q37_1': 0, 'Q37_2': 0, 'Q37_3': 0, 'Q37_4': 0, 'Q37_5': 0, 'Q37_6': 0, 'Q37_7': 0, 'Q37_8': 0, 
                   'Q37_9': 0, 'Q37_10': 0,'Q37_11': 0, 'Q37_12': 0, 'Q37_13': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 561
# 396
# 350
# 123
# 448
# 104
# 99
# 113
# 30
# 52
# 114
# 3016
# 121

# %%
emount_counts = start_ds['Q37_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q37_Emount
# 0     19325
# 1      4166
# 2       324
# 3       112
# 4        42
# 5         8
# 6         6
# 11        5
# 7         3
# 10        2
# 8         2
# 9         1
# 12        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 38_1-38_8
Do you use any of the following automated machine learning tools? (Select all that apply)
● Google Cloud AutoML
● H20 Driverless AI
● Databricks AutoML
● DataRobot AutoML
● Amazon Sagemaker Autopilot
● Azure Automated Machine Learning
● No / None
● Othe

# %%
columns_range = [f'Q38_{i}' for i in range(1, 9)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q38_1 Q38_2 Q38_3 Q38_4 Q38_5 Q38_6      Q38_7 Q38_8
# 0       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN  No / None   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# ...     ...   ...   ...   ...   ...   ...        ...   ...
# 23992   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23993   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23994   NaN   NaN   NaN   NaN   NaN   NaN  No / None   NaN
# 23995   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
# 23996   NaN   NaN   NaN   NaN   NaN   NaN        NaN   NaN
#
# [23997 rows x 8 columns]

# %%
question_counts = {'Q38_1': 0, 'Q38_2': 0, 'Q38_3': 0, 'Q38_4': 0, 'Q38_5': 0, 'Q38_6': 0, 'Q38_7': 0, 'Q38_8': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 463
# 122
# 193
# 125
# 261
# 323
# 3536
# 127

# %%
emount_counts = start_ds['Q38_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q38_Emount
# 0    19343
# 1     4337
# 2      212
# 3       66
# 4       19
# 6       13
# 5        6
# 7        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 39_1-39_12
Do you use any of the following products to serve your machine learning models? (Select all that
apply)
● TensorFlow Extended (TFX)
● TorchServe
● ONNX Runtime
● Triton Inference Server
● OpenVINO Model Server
● KServe
● BentoML
● Multi Model Server (MMS)
● Seldon Core
● MLflow
● Other
● None

# %%
columns_range = [f'Q39_{i}' for i in range(1, 13)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q39_1 Q39_2           Q39_3 Q39_4 Q39_5 Q39_6 Q39_7 Q39_8 Q39_9 Q39_10  \
# 0       NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 1       NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 2       NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 3       NaN   NaN   ONNX Runtime    NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 4       NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# ...     ...   ...             ...   ...   ...   ...   ...   ...   ...    ...
# 23992   NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 23993   NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 23994   NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 23995   NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 23996   NaN   NaN             NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#        Q39_11 Q39_12
# 0         NaN    NaN
# ...

# %%
question_counts = {'Q39_1': 0, 'Q39_2': 0, 'Q39_3': 0, 'Q39_4': 0, 'Q39_5': 0, 'Q39_6': 0, 'Q39_7': 0, 'Q39_8': 0, 
                   'Q39_9': 0, 'Q39_10': 0,'Q39_11': 0, 'Q39_12': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 522
# 167
# 224
# 70
# 93
# 63
# 53
# 62
# 47
# 621
# 0
# 129

# %%
emount_counts = start_ds['Q39_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q39_Emount
# 0     22676
# 1       895
# 2       276
# 3        87
# 4        34
# 5        10
# 6         6
# 10        6
# 9         4
# 7         2
# 11        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 40_1-40_15
Do you use any tools to help monitor your machine learning models and/or experiments? (Select all
that apply)
● Neptune.ai
● Weights & Biases
● Comet.ml
● TensorBoard
● Guild.ai
● ClearML
● MLflow
● Aporia
● Evidently AI
● Arize
● WhyLabs
● Fiddler
● DVC
● No / None
● Other

# %%
columns_range = [f'Q40_{i}' for i in range(1, 16)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q40_1               Q40_2 Q40_3          Q40_4 Q40_5 Q40_6 Q40_7 Q40_8  \
# 0       NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 1       NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 2       NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 3       NaN   Weights & Biases    NaN   TensorBoard    NaN   NaN   NaN   NaN
# 4       NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# ...     ...                 ...   ...            ...   ...   ...   ...   ...
# 23992   NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 23993   NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 23994   NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 23995   NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
# 23996   NaN                 NaN   NaN            NaN   NaN   NaN   NaN   NaN
#
# ...

# %%
question_counts = {'Q40_1': 0, 'Q40_2': 0, 'Q40_3': 0, 'Q40_4': 0, 'Q40_5': 0,
                   'Q40_6': 0, 'Q40_7': 0, 'Q40_8': 0, 'Q40_9': 0, 'Q40_10': 0, 'Q40_11': 0,
                   'Q40_12': 0, 'Q40_13': 0, 'Q40_14': 0, 'Q40_15': 0, }

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 128
# 381
# 56
# 855
# 35
# 73
# 659
# 24
# 52
# 39
# 32
# 65
# 143
# 2930
# 124

# %%
emount_counts = start_ds['Q40_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q40_Emount
# 0     19374
# 1      4044
# 2       384
# 3       123
# 4        42
# 5        11
# 13        8
# 6         5
# 7         2
# 11        2
# 8         1
# 14        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q41
Do you use any of the following responsible or ethical AI products in your machine learning
practices? (Select all that apply)
● Google Responsible AI Toolkit (LIT, What-If Tools, Fairness Indicator, TensorFlow Data
Validation, TensorFlow Privacy, etc.)
● Microsoft Responsible AI Toolbox (Fairlearn, Counterfit, InterpretML, SmartNoise, etc.)
● IBM AI Ethics tools (AI Fairness 360, Adversarial Robustness Toolbox, AI Explainability 360,
etc.)
● Amazon AI Ethics Tools (Clarify, A2I, etc)
● The LinkedIn Fairness Toolkit (LiFT)
● Audit-AI
● Aequitas
● None
● Other

# %%
columns_range = [f'Q41_{i}' for i in range(1, 10)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#       Q41_1 Q41_2 Q41_3 Q41_4 Q41_5 Q41_6 Q41_7  Q41_8 Q41_9
# 0       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 1       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 3       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 4       NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# ...     ...   ...   ...   ...   ...   ...   ...    ...   ...
# 23992   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23993   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23994   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23995   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23996   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
#
# [23997 rows x 9 columns]

# %%
question_counts = {'Q41_1': 0, 'Q41_2': 0, 'Q41_3': 0, 'Q41_4': 0, 'Q41_5': 0,
                   'Q41_6': 0, 'Q41_7': 0, 'Q41_8': 0, 'Q41_9': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 289
# 206
# 128
# 184
# 80
# 69
# 36
# 0
# 96

# %%
emount_counts = start_ds['Q41_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q41_Emount
# 0    23303
# 1      467
# 2      136
# 3       56
# 4       17
# 7        6
# 5        5
# 6        5
# 8        2
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q 42_1-42_9
Do you use any of the following types of specialized hardware when training machine learning
models? (Select all that apply)
● GPUs
● TPUs
● IPUs
● WSEs
● RDUs
● Trainium Chips
● Inferentia Chips
● None
● Other

# %%
columns_range = [f'Q42_{i}' for i in range(1, 10)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#         Q42_1 Q42_2 Q42_3 Q42_4 Q42_5 Q42_6 Q42_7  Q42_8 Q42_9
# 0         NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 1         NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 3       GPUs    NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# ...       ...   ...   ...   ...   ...   ...   ...    ...   ...
# 23992     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23993     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23994     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23995     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
# 23996     NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN   NaN
#
# [23997 rows x 9 columns]

# %%
question_counts = {'Q42_1': 0, 'Q42_2': 0, 'Q42_3': 0, 'Q42_4': 0, 'Q42_5': 0,
                   'Q42_6': 0, 'Q42_7': 0, 'Q42_8': 0, 'Q41_9': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 2682
# 653
# 67
# 58
# 26
# 39
# 58
# 0
# 96

# %%
emount_counts = start_ds['Q42_10'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q42_10
# 0    21166
# 1     2135
# 2      629
# 3       41
# 4       12
# 7        7
# 5        4
# 6        2
# 8        1
# Name: count, dtype: int64

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q43
Approximately how many times have you used a TPU (tensor processing unit)?
● Never
● Once
● 2-5 times
● 6-25 times
● More than 25 times

# %%
position_counts = start_ds['Q43'].value_counts()
print("Скільки разів ви використовували TPU (тензорний процесор)")
print(position_counts)
# Out:
# Скільки разів ви використовували TPU (тензорний процесор)
# Q43
# Never                 2538
# 2-5 times              958
# Once                   612
# 6-25 times             260
# More than 25 times     225
# Name: count, dtype: int64

# %%
plt.pie(position_counts.values, labels=position_counts.index, autopct="%1.1f%%")
plt.title("Скільки разів ви використовували TPU (тензорний процесор)")
plt.show()

# %%
#*********************************************************************************
#*********************************************************************************

# %%
Q44
Who/what are your favorite media sources that report on data science topics? (Select all that apply)
● Twitter (data science influencers)
● Email newsletters (Data Elixir, O'Reilly Data & AI, etc)
● Reddit (r/machinelearning, etc)
● Kaggle (notebooks, forums, etc)
● Course Forums (forums.fast.ai, Coursera forums, etc)
● YouTube (Kaggle YouTube, Cloud AI Adventures, etc)
● Podcasts (Chai Time Data Science, O’Reilly Data Show, etc)
● Blogs (Towards Data Science, Analytics Vidhya, etc)
● Journal Publications (peer-reviewed journals, conference proceedings, etc)
● Slack Communities (ods.ai, kagglenoobs, etc)
● None
● Other

# %%
# Вибираємо стовпці від Q44_1 до Q44_12
columns_range = [f'Q44_{i}' for i in range(1, 13)]
range_data = start_ds[columns_range]
print(range_data)
# Out:
#                                     Q44_1  \
# 0                                     NaN
# 1                                     NaN
# 2      Twitter (data science influencers)
# 3      Twitter (data science influencers)
# 4                                     NaN
# ...                                   ...
# 23992                                 NaN
# 23993                                 NaN
# 23994  Twitter (data science influencers)
# 23995                                 NaN
# 23996                                 NaN
#
#                                                    Q44_2 Q44_3  \
# 0                                                    NaN   NaN
# 1                                                    NaN   NaN
# 2      Email newsletters (Data Elixir, O'Reilly Data ...   NaN
# 3                                                    NaN   NaN
# 4                                                    NaN   NaN
# ...                                                  ...   ...
# ...

# %%
question_counts = {'Q44_1': 0, 'Q44_2': 0, 'Q44_3': 0, 'Q44_4': 0, 'Q44_5': 0,
                   'Q44_6': 0, 'Q44_7': 0, 'Q44_8': 0, 'Q44_9': 0, 'Q44_10': 0, 'Q44_11': 0,
                   'Q44_12': 0}

for col in question_counts.keys():
    question_counts[col] = start_ds[col].count()
    
print("Кількість відповідей для кожного питання:")
for question, count in question_counts.items():
    print(count)

plt.bar(question_counts.keys(), question_counts.values())
plt.xlabel('Питання')
plt.ylabel('Кількість відповідей')
plt.title('Кількість відповідей для кожного питання')
plt.xticks(rotation=45)
plt.show()
# Out:
# Кількість відповідей для кожного питання:
# 3995
# 3787
# 2678
# 11181
# 4006
# 11957
# 2120
# 7766
# 3804
# 1726
# 0
# 835

# %%
emount_counts = start_ds['Q44_Emount'].value_counts()
print("Кількість вибору")
print(emount_counts)

plt.pie(emount_counts.values, labels=emount_counts.index, autopct="%1.1f%%")
plt.title("Кількість вибраних варіантів відповідей")
plt.show()
# Out:
# Кількість вибору
# Q44_Emount
# 0     5574
# 2     4503
# 3     4386
# 1     3924
# 4     2809
# 5     1491
# 6      690
# 7      314
# 8      136
# 10      94
# 9       63
# 11      13
# Name: count, dtype: int64
